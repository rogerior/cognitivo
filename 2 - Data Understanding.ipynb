# %% [markdown]
# ### Carregar bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Carregar dados

# %%
dados = pd.read_csv('dados/winequality.csv', sep=';')

dados.head(10)
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  White            7.0              0.27         0.36            20.7
# 1  White            6.3              0.30         0.34             1.6
# 2  White            8.1              0.28         0.40             6.9
# 3  White            7.2              0.23         0.32             8.5
# 4  White            7.2              0.23         0.32             8.5
# 5  White            8.1              0.28         0.40             6.9
# 6  White            6.2              0.32         0.16             7.0
# 7  White            7.0              0.27         0.36            20.7
# 8  White            6.3              0.30         0.34             1.6
# 9  White            8.1              0.22         0.43             1.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# ...

# %% [markdown]
# ### Quantidade de linhas e colunas

# %%
dados.shape
# Out:
# (6497, 13)

# %% [markdown]
# ### Descrição estatística dos atributos númericos

# %%
dados.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     1.710882
# std       0.035034            17.749400             56.521855     7.636088
# ...

# %% [markdown]
# O atributo alcohol não foi exibido na descrição estatística dos atributos númericos, verificando o que ocasionou a sua ausência:

# %% [markdown]
# ### Tipos dos atributos

# %%
dados.dtypes
# Out:
# type                     object
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                  object
# quality                   int64
# dtype: object

# %% [markdown]
# Segundo o entendimento obtido na etapa de Business Understanding, o atributo alcohol representa o teor alcoólico do vinho, portanto este atributo deve ser do tipo númerico.
#
# Verificar motivo desse atributo estar como object

# %%
dados.alcohol.unique()
# Out:
# array(['8.8', '9.5', '10.1', '9.9', '9.6', '11', '12', '9.7', '10.8',
#        '12.4', '11.4', '12.8', '11.3', '10.5', '9.3', '10', '10.4',
#        '11.6', '12.3', '10.2', '9', '11.2', '8.6', '9.4', '9.8', '11.7',
#        '10.9', '9.1', '8.9', '10.3', '12.6', '10.7', '12.7', '10.6',
#        '9.2', '8.7', '11.5', '11.8', '12.1', '11.1', '8.5', '12.5',
#        '11.9', '12.2', '12.9', '13.9', '14', '13.5', '13.3', '13.2',
#        '13.7', '13.4', '13', '8', '13.1', '8.0', '13.6', '8.4', '14.2',
#        '11.94', '128.933.333.333.333', '114.666.666.666.667', '10.98',
#        '100.333.333.333.333', '114.333.333.333.333',
#        '105.333.333.333.333', '953.333.333.333.333',
#        '109.333.333.333.333', '113.666.666.666.667',
#        '113.333.333.333.333', '110.666.666.666.667',
#        '973.333.333.333.333', '11.05', '9.75', '11.35', '9.55', '10.55',
#        '11.45', '14.05', '123.333.333.333.333', '12.75', '13.8', '12.15',
# ...

# %% [markdown]
# A presença de valores do tipo "973.333.333.333.333" faz com que este atributo não seja convertido para algum tipo númerico, na etapa de "Data Preparation" este tributo será tratado.

# %% [markdown]
# ### Verificar se existe valores nulos nos dados

# %%
dados.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# O conjunto de dados não tem nenhum dado faltante (nulo)

# %% [markdown]
# ### Verificar a presença de outliers

# %%
dados.columns
# Out:
# Index(['type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
# Selecionar todas as colunas exceto as: 'type' e 'quality'
atributos_boxplot = ['fixed acidity', 'volatile acidity', 'citric acid',
       'residual sugar', 'chlorides', 'free sulfur dioxide',
       'total sulfur dioxide', 'density', 'pH', 'sulphates']

for atributo in atributos_boxplot:
    plt.figure()
    sns.boxplot(dados[atributo], orient='vertical')

# %% [markdown]
# Podemos perceber que todas as colunas apresentam grande quantidade de outliers, nas próximas etapas será necessário aplicar técnicas para tratar esses outliers

# %% [markdown]
# ### Visualizar relação entre atributos

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.pairplot(dados, hue='quality')

# %%
sns.pairplot(dados, hue='type')

# %% [markdown]
# ### Identificar correlações entre os atributos

# %%
plt.figure(figsize=(20,10))
sns.heatmap(dados.corr(), annot=True)

# %% [markdown]
# ****
# # Próxima etapa: "Data Preparation"
